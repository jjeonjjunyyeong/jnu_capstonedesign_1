# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

import re
import time
import pandas as pd

# %%
def page_down(driver):
    for _ in range(20):
        body = driver.find_element(By.CSS_SELECTOR, '#QA0Szd > div > div > div.w6VYqd > div:nth-child(2) > div > div.e07Vkf.kA9KIf > div > div > div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd > div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd')
        body.send_keys(Keys.PAGE_DOWN)
        body.send_keys(Keys.PAGE_DOWN)
        body.send_keys(Keys.PAGE_DOWN)
        time.sleep(2)

def separate_to_grade(places, location):
        return places

def url_parse(url):
    parse = re.search(r'@([-+]?\d*\.\d+|\d+),([-+]?\d*\.\d+|\d+)', url)
    # parse = re.search(r'!3d([\d.]+)!4d([\d.]+)', url)   
    if parse:
        lat = float(parse.group(1))
        lon = float(parse.group(2))
        return lat, lon
    else:
        return None

# %%
driver = webdriver.Chrome()
# parse = re.search(r'!3d([\d.]+)!4d([\d.]+)', url)
# 1. 구글 지도 접속
driver.get('https://www.google.com/maps/?entry=ttu')
time.sleep(2)

driver.find_element(By.CSS_SELECTOR, "input#searchboxinput").send_keys('오사카 명소') # 일본 지역 크롤링 후 format으로 바꿔서 사용
driver.find_element(By.CSS_SELECTOR, "button#searchbox-searchbutton").click()
time.sleep(2)

driver.find_element(By.CSS_SELECTOR, '#assistive-chips > div > div > div > div.e07Vkf.kA9KIf > div > div > div > div > div.rHNip.cRLbXd > div.dryRY > div:nth-child(1) > button').click()
time.sleep(1)
driver.find_element(By.CSS_SELECTOR, '#action-menu > div:nth-child(7)').click()
time.sleep(2)
page_down(driver)

# %%
places = []
dataset = [0, 1, 2]
location = []
url_lst = []
count = 3
append_count = 0
url = ''
test_list =[]

# %%
while True:
    print(count)
    places_value = driver.find_element(By.CSS_SELECTOR, '#QA0Szd > div > div > div.w6VYqd > div.bJzME.tTVLSc > div > div.e07Vkf.kA9KIf > div > div > div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd > div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd > div:nth-child({})'.format(count))
    if(count == 119):
        print(places_value.text)
    if places_value.text == '마지막 항목입니다.':
        break

    # 예외 처리를 사용한 이유 : 
    # 각 div 태그의 순서가 달라 nth-child()를 사용할 수 없음
    # 이후 조금 더 효율적인 방법을 찾아야함
    try:
        driver.find_element(By.CSS_SELECTOR, '#QA0Szd > div > div > div.w6VYqd > div.bJzME.tTVLSc > div > div.e07Vkf.kA9KIf > div > div > div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd > div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd > div:nth-child({}) > div > a'.format(count)).click()
        time.sleep(2)
        test_list.append(driver.find_element(By.CSS_SELECTOR, '#QA0Szd > div > div > div.w6VYqd > div.bJzME.Hu9e2e.tTVLSc > div > div.e07Vkf.kA9KIf > div > div > div.m6QErb.DxyBCb.kA9KIf.dS8AEf > div.TIHn2 > div > div.lMbq3e > h2'))
        # location.append(driver.find_element(By.CSS_SELECTOR, '#QA0Szd > div > div > div.w6VYqd > div.bJzME.Hu9e2e.tTVLSc > div > div.e07Vkf.kA9KIf > div > div > div.m6QErb.DxyBCb.kA9KIf.dS8AEf > div:nth-child(11) > div:nth-child(3) > button > div > div.rogA2c > div.Io6YTe.fontBodyMedium.kR99db').text)
        location.append(driver.find_element(By.CSS_SELECTOR, '#QA0Szd > div > div > div.w6VYqd > div.bJzME.tTVLSc > div > div.e07Vkf.kA9KIf > div > div > div.TIHn2 > div > div.lMbq3e > h2').text)
        driver.find_element(By.CSS_SELECTOR, '#QA0Szd > div > div > div.w6VYqd > div.bJzME.Hu9e2e.tTVLSc > div > div.e07Vkf.kA9KIf > div > div > div.BHymgf.eiJcBe.bJUD0c > div > div > div:nth-child(3) > span > button').click()
        time.sleep(2)
    except:
        location.append('None')
        
    places_value = places_value.text.split('\n')
    print(places_value)
    places.append([])
    for i in dataset:
        places[append_count].append(places_value[i])
    append_count += 1
    count += 2
print(test_list)
# Out:
# 3
# ['오사카 성 천수각', '4.5(4,250)', '관광 명소 · 1-1 Osakajo', '오사카성에 있는 화려한 다층탑', '영업 종료 ⋅ 월 오전 9:00에 영업 시작', '  "역시 오사카를 대표하는 랜드마크 명소!!"']
# 5
# ['유니버설 스튜디오 재팬', '4.5(106,863)', '관광 명소 · 2 Chome-1-33 Sakurajima', '놀이기구가 있는 영화 테마의 놀이공원', '  "오사카를 방문하시면 꼭 다녀오셔야 할 명소입니다."']
# 7
# ['태양의 탑', '4.5(5,444)', '관광 명소 · 1-1 Senribanpakukoen', '1970년대에 만들어진 독특하고 거대한 조각물', '영업 종료 ⋅ 월 오전 10:00에 영업 시작']
# 9
# ['아키바 카트 오사카', '4.9(1,122)', '관광 명소 · 3 Chome-3-9 Nipponbashi', '영업 종료 ⋅ 월 오전 10:00에 영업 시작', '  "아키바 카트로 오사카 주요 명소를 볼수있어 정말 즐거웠습니다."']
# 11
# ['Tea Ceremony Osaka The Osaka(茶道体験The Osaka)', '5.0(525)', '관광 명소 · Dotonbori, 1 Chome−東５−26 道頓堀ビル 2F', '영업 종료 ⋅ 월 오전 10:00에 영업 시작']
# 13
# ['덴포잔 관람차', '5.0(4)', '관광 명소 · 1 Chome-1-10 Kaigandori', '  "오사카주유패스로 무료로 이용했고, 왼쪽줄은 바닥이 막힌 거 기다리는 ..."']
# 15
# ['スパイダーマンの館', '4.5(2)', '관광 명소 · 1 Chome Dotonbori']
# 17
# ['Karabori', '4.5(2)', '관광 명소 · 2 Osakajo']
# 19
# ['아사히맥주 스이타공장', '4.5(750)', '기술 박물관 · 1-45 Nishinoshocho', '오디오 투어와 시음이 가능한 대규모 양조장', '영업 종료 ⋅ 월 오전 9:30에 영업 시작', '  "오사카에', '여러번 온 사람이라면 외곽으로 바람쐬러 나올만한 곳."']
# 21
# ['사천왕사', '4.3(9,827)', '관광 명소 · 1 Chome-11-18 Shitennoji', '6세기에 지은 불교 사찰', '영업 종료 ⋅ 월 오전 8:30에 영업 시작', '  "오사카 주유패스로 들어갈수있는 정원이 정말 아름다움 절 분위기도 좋음"']
# 23
# ['도톤보리', '4.4(64,282)', '관광 명소 · 1 Chome Dotonbori', '음식점 및 극장으로 유명한 지역', '24시간 영업', '  "역시 오사카 명소라서 사람 많고 식당도 많다."']
# 25
# ['오사카 성', '4.4(65,121)', '관광 명소 · 1-1 Osakajo', '박물관이 있는 유명하고 역사 깊은 성', '영업 종료 ⋅ 월 오전 9:00에 영업 시작', '  "명실상부 오사카 최고명소."']
# 27
# ['해유관', '4.4(40,072)', '관광 명소 · 1 Chome-1-10 Kaigandori', '해양생물 전시회가 열리는 거대한 랜드마크', '영업 종료 ⋅ 월 오전 10:30에 영업 시작', '  "오사카 여행중 한번 방문하는것을 추천!"']
# 29
# ['덴포잔 대관람차', '4.4(8,062)', '관광 명소 · 1 Chome-1-10 Kaigandori', '전망을 감상할 수 있는 대규모 놀이 기구', '곧 영업 종료: 오후 10:00 ⋅ 월 오전 10:00에 영업 시작', '  "오사카 항구를 조망할 수 있는 관람차입니다."']
# 31
# ['쓰텐가쿠', '4.0(28,804)', '관광 명소 · 1 Chome-18-6 Ebisuhigashi', '전망대가 있는 상징적인 타워', '영업 종료 ⋅ 월 오전 10:00에 영업 시작', '  "오사카에서 가장 유명한 관광코스 중 하나지만 정작 가면 실망할 수도."']
# 33
# ['법선사', '4.3(3,066)', '관광 명소 · 1 Chome-2-16 Nanba', '이끼 덮인 불상이 있는 사원', '24시간 영업', '  "오사카 시내에 있어서 잠깐 구경하는게 좋아요"']
# 35
# ['우메다 스카이빌딩', '4.3(26,583)', '관광 명소 · 1 Chome-1-88 Oyodonaka', '옥상 정원 전망대가 있는 고층 건물', '영업 중 ⋅ 오후 10:30에 영업 종료', '  "오사카 풍경을 둘러보기 좋아요"']
# 37
# ['오사카 성 공원', '4.3(37,232)', '관광 명소 · 1-1 Osakajo', '정원과 성이 있는 도시 속 커다란 공원', '24시간 영업', '  "오사카에 왔다면, 꼭 들려야할 관광명소."']
# 39
# ['니시노마루 정원', '4.1(1,608)', '관광 명소 · 2 Osakajo', '벚꽃이 있는 매력적인 도심 공원', '영업 종료 ⋅ 화 오전 9:00에 영업 시작']
# 41
# ['우메다 공중정원', '4.4(10,704)', '관광 명소 · Oyodonaka, 1 Chome−1−88 梅田スカイビル', '멋진 전망과 음식을 즐길 수 있는 현대적인 전망대', '곧 영업 종료: 오후 10:00 ⋅ 월 오전 9:30에 영업 시작', '  "오사카에서 가장 좋아하는 야경 명소"']
# 43
# ['구치나와자카', '4.0(123)', '관광 명소 · 5-3 Yuhigaokacho', '24시간 영업']
# 45
# ['하마데라 공원', '4.1(3,715)', '관광 명소 · Hamadera Koencho', '장미 정원이 있는 공원', '24시간 영업', '  "오사카의 숨은 명소라기보다는 한번쯤 다들 가보길 원합니다 !"']
# 47
# ['덴덴타운 닛폰바시전기가', '4.1(6,008)', '상업 지구 · Nipponbashi', '첨단 기술, 애니메이션, 만화 전문 쇼핑 지구', '영업 종료 ⋅ 월 오전 11:00에 영업 시작', '  "오사카의 아키하바라 같은곳임."']
# 49
# ['나카노시마 장미 정원', '4.2(5,377)', '관광 명소 · 1 Chome-1 Nakanoshima', '박물관과 도서관이 있는 공원', '24시간 영업', '  "오사카 유명한 관광지도 많지만', '로컬 시민들이 찾는 장소로 좋았다."']
# 51
# ['오사카 기업가 뮤지엄', '4.0(208)', '관광 명소 · Honmachi, 1 Chome−4−5 B1階', '영업 종료 ⋅ 화 오전 10:00에 영업 시작', '  "오사카 기업가에 대해 자세한 설명을 들을수있는곳."']
# 53
# ['글리코 기념관', '4.2(146)', '관광 명소 · 4 Chome-5-5 Utajima']
# 55
# ['니프렐', '4.2(5,770)', '관광 명소 · Senribanpakukoen, 2−1 ＮＩＦＲＥＬ 2 階', '미래 지향적인 느낌의 수족관과 동물원', '영업 종료 ⋅ 월 오전 10:00에 영업 시작']
# 57
# ['오사카 이쿠노 코리아타운', '4.0(7,698)', '상업 지구 · 3 Chome-10-5 Momodani', '한국 식당과 상점이 있는 지역', '  "평일 낮시간인데도 많이 붐비네요..오사카 가면 꼭 가볼만한곳.."']
# 59
# ['가미가타우키요에관', '4.1(354)', '미술관 · 1 Chome-6-4 Nanba', '문화 예술작품이 있는 작은 미술관', '영업 종료 ⋅ 화 오전 11:00에 영업 시작', '  "Visit together with the Osaka Ukiyo-e museum, which is only five ..."']
# 61
# ['덴포잔 하버 빌리지', '4.1(920)', '관광 명소 · 1 Chome-1-10 Kaigandori', '쇼핑과 엔터테인먼트를 즐길 수 있는 단지', '영업 종료 ⋅ 월 오전 10:00에 영업 시작', '  "대관람차에서 오사카항이 보이고 오사카 유니버셜 스튜디오도 보입니다."']
# 63
# ['스미요시 공원', '4.0(1,221)', '관광 명소 · 1 Chome-1-13 Hamaguchihigashi', '24시간 영업']
# 65
# ['이케다 성터', '4.2(362)', '공원 · 3-19 Shiroyamacho', '영업 종료 ⋅ 월 오전 9:00에 영업 시작', '  "I will visit again if I come to Osaka next time."']
# 67
# ['헵파이브 관람차', '4.4(3,424)', '관광 명소 · Kakudacho, 5−15 HEP FIVE 7F', '쇼핑몰 꼭대기에 있는 거대한 붉은 대관람차', '영업 중 ⋅ 오후 10:45에 영업 종료', '  "오사카명소 저녁에 멋짐"']
# 69
# ['삼하라 신사', '4.3(2,750)', '관광 명소 · 2 Chome-5-26 Itachibori', '보호 능력을 지닌 신비한 유물이 있는 신사', '영업 종료 ⋅ 월 오전 9:00에 영업 시작']
# 71
# ['사카이시 박물관', '4.0(930)', '관광 명소 · Mozusekiuncho, 2 Chome, 大仙公園内', '영업 종료 ⋅ 화 오전 9:30에 영업 시작']
# 73
# ['Osaka Convention & Tourism Bureau', '4.0(37)', '협회 또는 조직 · Minamisenba, 4 Chome−4−21 TODA BUILDING心斎橋 5階', '안내서가 구비된 세련된 관광 안내소', '  "여행 팁과 길 안내, 명소 안내서를 제공하는 현대적인 관광 안내소 ..."']
# 75
# ['사쿠라노미야 신사', '4.0(220)', '관광 명소 · 1 Chome-12-32 Nakanocho', '24시간 영업']
# 77
# ['승미사', '4.3(5,206)', '관광 명소 · 2914-1 Aomatani', '영업 종료 ⋅ 월 오전 8:00에 영업 시작']
# 79
# ['오사카 수상버스 아쿠아라이너', '4.2(543)', '관광 명소 · 2 Osakajo', '  "수로를 따라 오사카 유람~~좋아요~"']
# 81
# ['천연온천 나니와노유', '4.1(6,077)', '관광 명소 · 1 Chome-7-31 Nagaranishi', '도심에 자리한 천연 온천 스파', '영업 중 ⋅ 오전 1:00에 영업 종료', '  "오사카 주유패스가 있음 올만 함."']
# 83
# ['아마가세 구름다리', '4.1(400)', '다리 · Uji', '24시간 영업']
# 85
# ['사천왕사 석무대', '4.1(50)', '관광 명소 · 1 Chome-11-18 Shitennoji', '24시간 영업']
# 87
# ['쓰루하시', '리뷰 없음', '일본', '〒544-0031 오사카부 오사카시 이쿠노구']
# 89
# ['언덕', '리뷰 없음', '관광 명소 · 2 Chome-5 Sakurazaka']
# 91
# ['우키요코지', '4.3(101)', '상업 지구 · 1 Chome-7-22 Dotonbori', '24시간 영업', '  "오사카의 명물 우동가게로 유명한 도톤버리 이마이 바로 옆에 있는데, 이곳을 통과하면 호젠 ..."']
# 93
# ['조례호수공원', '4.4(2,669)', '관광 명소 · 왕지2길 20', '24시간 영업', '  "산책하기 좋고 경치가 좋은 순천의 명소입니다."']
# 95
# ['니시키 시장', '4.2(33,408)', '관광 명소', '일본 제품을 판매하는 유서 깊은 시장', '  "오사카의 구로몬 시장보다 훨씬 더 현지 시장에 가까운 느낌입니다."']
# 97
# ['스이젠지 조주엔', '4.3(5,119)', '관광 명소 · 8-1 Suizenji Koen', '17세기 조성된 고요한 정원', '영업 종료 ⋅ 월 오전 8:30에 영업 시작', '  "오사카에 살고 있지만 쿠마모토도 생각보다 좋은 도시였습니다."']
# 99
# ['교토 부청 1호관', '4.0(468)', '관광 명소 · 薮ノ内町', '서양식 건축물과 벚나무', '영업 종료 ⋅ 화 오전 10:00에 영업 시작']
# 101
# ['혼마치바시', '리뷰 없음', '일본', '〒540-0029 오사카부 오사카시 주오구']
# 103
# ['지라이언 뮤지엄', '4.2(1,212)', '박물관 · 2 Chome-6-39 Kaigandori', '창고에 자리한 클래식 자동차 박물관', '영업 종료 ⋅ 화 오전 11:00에 영업 시작', '  "... 오사카 주유패스를 가지고 있으시다면 가볼 만 ... 교토 최고의 명소 ..."']
# 105
# ['고베 하버랜드', '4.2(7,740)', '상업 지구 · 1 Chome Higashikawasakicho', '항구 인근의 쇼핑 및 엔터테인먼트 지역', '영업 종료 ⋅ 월 오전 10:00에 영업 시작', '  "사람도 오사카나 교토에 비해 많지 않아 북적북적 하지 않고요!"']
# 107
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# c:\Users\wnsdu\Desktop\capstone\crawling\Region\org_Resion_crawling.ipynb 셀 5 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/wnsdu/Desktop/capstone/crawling/Region/org_Resion_crawling.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> while True:
#       <a href='vscode-notebook-cell:/c%3A/Users/wnsdu/Desktop/capstone/crawling/Region/org_Resion_crawling.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a>     print(count)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/wnsdu/Desktop/capstone/crawling/Region/org_Resion_crawling.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a>     places_value = driver.find_element(By.CSS_SELECTOR, '#QA0Szd > div > div > div.w6VYqd > div.bJzME.tTVLSc > div > div.e07Vkf.kA9KIf > div > div > div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd > div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd > div:nth-child({})'.format(count))
#       <a href='vscode-notebook-cell:/c%3A/Users/wnsdu/Desktop/capstone/crawling/Region/org_Resion_crawling.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a>     if(count == 119):
#       <a href='vscode-notebook-cell:/c%3A/Users/wnsdu/Desktop/capstone/crawling/Region/org_Resion_crawling.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a>         print(places_value.text)
#
# File c:\Users\wnsdu\anaconda3\envs\capstone\Lib\site-packages\selenium\webdriver\remote\webdriver.py:738, in WebDriver.find_element(self, by, value)
#     735     by = By.CSS_SELECTOR
#     736     value = f'[name="{value}"]'
# --> 738 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\wnsdu\anaconda3\envs\capstone\Lib\site-packages\selenium\webdriver\remote\webdriver.py:344, in WebDriver.execute(self, driver_command, params)
#     342 response = self.command_executor.execute(driver_command, params)
#     343 if response:
# --> 344     self.error_handler.check_response(response)
#     345     response["value"] = self._unwrap_value(response.get("value", None))
#     346     return response
#
# File c:\Users\wnsdu\anaconda3\envs\capstone\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"#QA0Szd > div > div > div.w6VYqd > div.bJzME.tTVLSc > div > div.e07Vkf.kA9KIf > div > div > div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd > div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd > div:nth-child(107)"}
#   (Session info: chrome=119.0.6045.160); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF6528182B2+55298]
# 	(No symbol) [0x00007FF652785E02]
# 	(No symbol) [0x00007FF6526405AB]
# 	(No symbol) [0x00007FF65268175C]
# 	(No symbol) [0x00007FF6526818DC]
# 	(No symbol) [0x00007FF6526BCBC7]
# 	(No symbol) [0x00007FF6526A20EF]
# 	(No symbol) [0x00007FF6526BAAA4]
# 	(No symbol) [0x00007FF6526A1E83]
# 	(No symbol) [0x00007FF65267670A]
# 	(No symbol) [0x00007FF652677964]
# 	GetHandleVerifier [0x00007FF652B90AAB+3694587]
# 	GetHandleVerifier [0x00007FF652BE728E+4048862]
# 	GetHandleVerifier [0x00007FF652BDF173+4015811]
# 	GetHandleVerifier [0x00007FF6528B47D6+695590]
# 	(No symbol) [0x00007FF652790CE8]
# 	(No symbol) [0x00007FF65278CF34]
# 	(No symbol) [0x00007FF65278D062]
# 	(No symbol) [0x00007FF65277D3A3]
# 	BaseThreadInitThunk [0x00007FFA5232257D+29]
# 	RtlUserThreadStart [0x00007FFA52C2AA58+40]

# %%
# for i in range(len(location)):
#     location[i] = location[i].text
#     print(location[i])

location
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_96")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_121")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_156")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_185")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_216")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_237")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_261")>,
#  'None',
#  <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_324")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_358")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_390")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_409")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_434")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_455")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_486")>,
#  'None',
#  <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_523")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_548")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_576")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_595")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_628")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_648")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_680")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_702")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_721")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_751")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_794")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_822")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_862")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_903")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_948")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_979")>,
#  'None',
#  'None',
#  <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_1055")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_1099")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_1130")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_1184")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_1223")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_1254")>,
#  'None',
#  'None',
#  <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_1303")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_1344")>,
#  'None',
#  'None',
#  <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_1392")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_1429")>,
#  'None',
#  'None',
#  <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_1494")>]

# %%
for i in range(len(places)):
        places[i][1] = places[i][1].replace('(', ', ').replace(')', '') # 추가
        places[i].append(location[i])

# %%
places
# Out:
# [['사천왕사',
#   '4.3, 9,826',
#   '관광 명소 · 1 Chome-11-18 Shitennoji',
#   <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_96")>],
#  ['도톤보리',
#   '4.4, 64,280',
#   '관광 명소 · 1 Chome Dotonbori',
#   <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_121")>],
#  ['오사카 성',
#   '4.4, 65,118',
#   '관광 명소 · 1-1 Osakajo',
#   <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_156")>],
#  ['오사카 성 천수각',
#   '4.5, 4,250',
#   '관광 명소 · 1-1 Osakajo',
#   <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_185")>],
#  ['유니버설 스튜디오 재팬',
#   '4.5, 106,861',
#   '관광 명소 · 2 Chome-1-33 Sakurajima',
#   <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_216")>],
#  ['해유관',
#   '4.4, 40,071',
#   '관광 명소 · 1 Chome-1-10 Kaigandori',
#   <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_237")>],
#  ['덴포잔 대관람차',
#   '4.4, 8,062',
#   '관광 명소 · 1 Chome-1-10 Kaigandori',
#   <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_261")>],
#  ['조례호수공원', '4.4, 2,669', '관광 명소 · 왕지2길 20', 'None'],
#  ['쓰텐가쿠',
#   '4.0, 28,803',
#   '관광 명소 · 1 Chome-18-6 Ebisuhigashi',
#   <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_324")>],
#  ['법선사',
#   '4.3, 3,067',
#   '관광 명소 · 1 Chome-2-16 Nanba',
#   <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_358")>],
#  ['우메다 스카이빌딩',
#   '4.3, 26,582',
#   '관광 명소 · 1 Chome-1-88 Oyodonaka',
#   <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_390")>],
#  ['니시노마루 정원',
#   '4.1, 1,608',
#   '관광 명소 · 2 Osakajo',
#   <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_409")>],
#  ['오사카 성 공원',
#   '4.3, 37,232',
#   '관광 명소 · 1-1 Osakajo',
#   <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_434")>],
#  ['우메다 공중정원',
#   '4.4, 10,704',
#   '관광 명소 · Oyodonaka, 1 Chome−1−88 梅田スカイビル',
#   <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_455")>],
#  ['신우메다 시티',
#   '4.2, 5,002',
#   '관광 명소 · 1 Chome-1-88 Oyodonaka',
#   <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_486")>],
#  ['오사카초밥참치', '2.3, 4', '음식점 · 무안읍 교촌리 1041-6', 'None'],
#  ['난바 야사카 신사',
#   '4.4, 6,131',
#   '관광 명소 · 2 Chome-9-19 Motomachi',
#   <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_523")>],
#  ['아베노 하루카스',
#   '4.2, 45,852',
#   '상업 지구 · 1 Chome-1-43 Abenosuji',
#   <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_548")>],
#  ['태양의 탑',
#   '4.5, 5,444',
#   '관광 명소 · 1-1 Senribanpakukoen',
#   <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_576")>],
#  ['마이시마 녹지',
#   '3.9, 311',
#   '관광 명소 · 3',
#   <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_595")>],
#  ['오기마치 공원',
#   '3.9, 3,400',
#   '관광 명소 · 1 Chome-1 Ogimachi',
#   <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_628")>],
#  ['구치나와자카',
#   '4.0, 123',
#   '관광 명소 · 5-3 Yuhigaokacho',
#   <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_648")>],
#  ['하마데라 공원',
#   '4.1, 3,714',
#   '관광 명소 · Hamadera Koencho',
#   <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_680")>],
#  ['오사카 성 은곡륜',
#   '3.8, 46',
#   '관광 명소 · 1-1 Osakajo',
#   <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_702")>],
#  ['미쓰 공원',
#   '3.7, 1,101',
#   '관광 명소 · 2 Chome-11-34 Nishishinsaibashi',
#   <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_721")>],
#  ['덴덴타운 닛폰바시전기가',
#   '4.1, 6,008',
#   '상업 지구 · Nipponbashi',
#   <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_751")>],
#  ['나카노시마 장미 정원',
#   '4.2, 5,377',
#   '관광 명소 · 1 Chome-1 Nakanoshima',
#   <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_794")>],
#  ['글리코 기념관',
#   '4.2, 146',
#   '관광 명소 · 4 Chome-5-5 Utajima',
#   <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_822")>],
#  ['오사카 기업가 뮤지엄',
#   '4.0, 208',
#   '관광 명소 · Honmachi, 1 Chome−4−5 B1階',
#   <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_862")>],
#  ['니프렐',
#   '4.2, 5,769',
#   '관광 명소 · Senribanpakukoen, 2−1 ＮＩＦＲＥＬ 2 階',
#   <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_903")>],
#  ['오사카부 사키시마청사',
#   '3.8, 490',
#   '관광 명소 · 1 Chome-14-16 Nankokita',
#   <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_948")>],
#  ['오사카 과학기술관',
#   '3.7, 1,110',
#   '관광 명소 · 1 Chome-8-4 Utsubohonmachi',
#   <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_979")>],
#  ['현대그린농원', '3.6, 7', '식물원 · 삼례읍 신탁리 254-2', 'None'],
#  ['덴포잔 하버 빌리지', '4.1, 920', '관광 명소 · 1 Chome-1-10 Kaigandori', 'None'],
#  ['오사카 이쿠노 코리아타운',
#   '4.0, 7,698',
#   '상업 지구 · 3 Chome-10-5 Momodani',
#   <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_1055")>],
#  ['가미가타우키요에관',
#   '4.1, 354',
#   '미술관 · 1 Chome-6-4 Nanba',
#   <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_1099")>],
#  ['스미요시 공원',
#   '4.0, 1,221',
#   '관광 명소 · 1 Chome-1-13 Hamaguchihigashi',
#   <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_1130")>],
#  ['이케다 성터',
#   '4.2, 362',
#   '공원 · 3-19 Shiroyamacho',
#   <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_1184")>],
#  ['헵파이브 관람차',
#   '4.4, 3,424',
#   '관광 명소 · Kakudacho, 5−15 HEP FIVE 7F',
#   <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_1223")>],
#  ['삼하라 신사',
#   '4.3, 2,750',
#   '관광 명소 · 2 Chome-5-26 Itachibori',
#   <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_1254")>],
#  ['마비정벽화마을', '3.9, 1,063', '관광 명소 · 화원읍 본리리', 'None'],
#  ['사카이시 박물관', '4.0, 930', '관광 명소 · Mozusekiuncho, 2 Chome, 大仙公園内', 'None'],
#  ['아키바 카트 오사카',
#   '4.9, 1,120',
#   '관광 명소 · 3 Chome-3-9 Nipponbashi',
#   <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_1303")>],
#  ['Osaka Convention & Tourism Bureau',
#   '4.0, 37',
#   '협회 또는 조직 · Minamisenba, 4 Chome−4−21 TODA BUILDING心斎橋 5階',
#   <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_1344")>],
#  ['울산왜성', '4.1, 89', '관광 명소 · 학성공원3길 54', 'None'],
#  ['언덕', '리뷰 없음', '관광 명소 · 2 Chome-5 Sakurazaka', 'None'],
#  ['사쿠라노미야 신사',
#   '4.0, 220',
#   '관광 명소 · 1 Chome-12-32 Nakanocho',
#   <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_1392")>],
#  ['본원사 터',
#   '3.9, 42',
#   '관광 명소 · 2-2 Osakajo',
#   <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_1429")>],
#  ['롯데월드타워', '4.4, 46,162', '관광 명소 · 올림픽로 300', 'None'],
#  ['승미사', '4.3, 5,205', '관광 명소 · 2914-1 Aomatani', 'None'],
#  ['오사카 수상버스 아쿠아라이너',
#   '4.2, 543',
#   '관광 명소 · 2 Osakajo',
#   <selenium.webdriver.remote.webelement.WebElement (session="23146e8525cad6ccf72e748775ad3f98", element="F8150B0733102461F83EA358FB403626_element_1494")>]]

# %%
df = pd.DataFrame(places, columns=['name', 'score', 'category', 'location', 'lat', 'lon'])
df
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File c:\Users\wnsdu\anaconda3\envs\capstone\Lib\site-packages\pandas\core\internals\construction.py:939, in _finalize_columns_and_data(content, columns, dtype)
#     938 try:
# --> 939     columns = _validate_or_indexify_columns(contents, columns)
#     940 except AssertionError as err:
#     941     # GH#26429 do not raise user-facing AssertionError
#
# File c:\Users\wnsdu\anaconda3\envs\capstone\Lib\site-packages\pandas\core\internals\construction.py:986, in _validate_or_indexify_columns(content, columns)
#     984 if not is_mi_list and len(columns) != len(content):  # pragma: no cover
#     985     # caller's responsibility to check for this...
# --> 986     raise AssertionError(
#     987         f"{len(columns)} columns passed, passed data had "
#     988         f"{len(content)} columns"
#     989     )
#     990 if is_mi_list:
#     991     # check if nested list column, length of each sub-list should be equal
#
# AssertionError: 6 columns passed, passed data had 4 columns
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# c:\Users\wnsdu\Desktop\capstone\crawling\Region\Resion_crawling.ipynb 셀 9 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/wnsdu/Desktop/capstone/crawling/Region/Resion_crawling.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> df = pd.DataFrame(places, columns=['name', 'score', 'category', 'location', 'lat', 'lon'])
#       <a href='vscode-notebook-cell:/c%3A/Users/wnsdu/Desktop/capstone/crawling/Region/Resion_crawling.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> df
#
# File c:\Users\wnsdu\anaconda3\envs\capstone\Lib\site-packages\pandas\core\frame.py:809, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     807     if columns is not None:
#     808         columns = ensure_index(columns)
# --> 809     arrays, columns, index = nested_data_to_arrays(
#     810         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     811         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#     812         data,
#     813         columns,
#     814         index,  # type: ignore[arg-type]
#     815         dtype,
#     816     )
#     817     mgr = arrays_to_mgr(
#     818         arrays,
#     819         columns,
#    (...)
#     822         typ=manager,
#     823     )
#     824 else:
#
# File c:\Users\wnsdu\anaconda3\envs\capstone\Lib\site-packages\pandas\core\internals\construction.py:520, in nested_data_to_arrays(data, columns, index, dtype)
#     517 if is_named_tuple(data[0]) and columns is None:
#     518     columns = ensure_index(data[0]._fields)
# --> 520 arrays, columns = to_arrays(data, columns, dtype=dtype)
#     521 columns = ensure_index(columns)
#     523 if index is None:
#
# File c:\Users\wnsdu\anaconda3\envs\capstone\Lib\site-packages\pandas\core\internals\construction.py:845, in to_arrays(data, columns, dtype)
#     842     data = [tuple(x) for x in data]
#     843     arr = _list_to_arrays(data)
# --> 845 content, columns = _finalize_columns_and_data(arr, columns, dtype)
#     846 return content, columns
#
# File c:\Users\wnsdu\anaconda3\envs\capstone\Lib\site-packages\pandas\core\internals\construction.py:942, in _finalize_columns_and_data(content, columns, dtype)
#     939     columns = _validate_or_indexify_columns(contents, columns)
#     940 except AssertionError as err:
#     941     # GH#26429 do not raise user-facing AssertionError
# --> 942     raise ValueError(err) from err
#     944 if len(contents) and contents[0].dtype == np.object_:
#     945     contents = convert_object_array(contents, dtype=dtype)
#
# ValueError: 6 columns passed, passed data had 4 columns

# %%
df.to_csv('osaka_places.csv', index=False)

# %%
driver.quit()

# %%
print(location)
# Out:
# ['사천왕사\n四天王寺\n4.3\n(9,825)\n불교사찰\n개요\n리뷰\n정보\n\ue52e\n경로\n\ue866\n저장\n\uf05f\n주변\n\ue702\n휴대전화로 보내기\n\ue80d\n공유\n593년에 처음 지어져 복원된 불교 사찰로 5층탑, 불상, 거북이 연못이 있습니다.\n입장권\n검색 결과 정보\n장소 입장 가능\n사천왕사\n공식 사이트\n₩2,601\nAgoda\n₩16,270\n1 Chome-11-18 Shitennoji, Tennoji Ward, Osaka, 543-0051 일본\n영업 종료 ⋅ 월 오전 8:30에 영업 시작\nshitennoji.or.jp\n+81 6-6771-0066\nMG38+QJ 오사카시 일본 오사카부\n휴대전화로 보내기\n비즈니스에 대한 소유권 주장\n\ue3c9\n수정 제안하기\n고객의 업데이트\n２１日は早朝から、賑やか賑やか、、。\n5일 전\n  사진\n전체\n최신\n1일 전\n동영상\n육시예찬당\n이시도리이\n남대문\n성령원 경당\n중문\n대흑당\n스트리트 뷰 및 360°\n사진 추가\n디렉터리\n장소 검색\n식음료\n1\n서비스\n2\n주차\n1\n기타\n109\n사천왕사 본방\n4.3(131)\n불교사찰 · 1층\n24시간 영업\n사천왕사 오중탑\n4.3(125)\n불교사찰 · 1층\n영업 종료 ⋅ 월 오전 8:30에 영업 시작\n사천왕사 남대문\n4.3(95)\n불교사찰 · 1층\n24시간 영업\n사천왕사 이시도리이\n4.2(88)\n불교사찰 · 1층\n24시간 영업\n모두 보기\n질문과 답변\n(Google 번역) 커버 차지가 있나요? (원본) Is there a cover charge?\n(Google 번역) 예, 일반 400, 학생 200입니다. 어린이 100세 이하, 고등학생 이하는 무료입니다. (원본) Yes, 400 for general admittance, 200 for school students. Kids 100, and high school and lower are free.\n답변 3개 보기\n4년 전\n\n질문 더보기\n커뮤니티에 질문하기\n  리뷰 요약\n5\n4\n3\n2\n1\n4.3\n리뷰 9,825개\n리뷰 작성\n리뷰\n정렬\n전체\n쇼토쿠 태자\n321\n아베노 하루카스\n56\n스이코 천황\n32\n일본의 불교\n28\n모노노베노 모리야\n19\n일본서기\n17\n소가노 우마코\n16\n이안나\n지역 가이드 · 리뷰 16개 · 사진 23장\n4일 전\n신규\n매월 21,22일 벼룩시장 열립니다.\n정말 저렴하게 기모노 구매가능합니다.\n근데 여기 자체는 크게 매력있진 않습니다.\n방문일\n평일…\n자세히\n좋아요\n공유\nlunapsiesp\n지역 가이드 · 리뷰 117개 · 사진 572장\n4달 전\n배경을 모르더라도 사적에 대한 관심이 있다면 충분히 들를 가치가 있는 곳\n\n일본의 특징인진 모르겠지만 초목을 최대한 절제해… 자세히\n14개 더보기\n좋아요\n공유\n서영욱\n지역 가이드 · 리뷰 77개 · 사진 363장\n7달 전\n오사카 주유패스로 무료로 입장\n\n중심가람… 자세히\n3개 더보기\n2\n공유\n리뷰 더보기 (9,822)\n함께 검색한 장소\n일심사\n4.2(6,306)\n불교사찰\n청광원 청수사\n4.1(291)\n불교사찰\n통국사\n4.0(99)\n불교사찰\n사천왕사 중지문\n4.3(36)\n불교사찰\n사천왕사 동대문\n3.9(24)\n불교사찰\n  웹 검색결과\n  데이터 정보', '오사카초밥참치\n2.3\n(4)\n음식점\n개요\n리뷰\n정보\n\ue52e\n경로\n\ue866\n저장\n\uf05f\n주변\n\ue702\n휴대전화로 보내기\n\ue80d\n공유\n매장 내 식사\n·\n테이크아웃\n전라남도 무안군 무안읍 교촌리 1041-6\n영업 중 ⋅ 오후 9:00에 영업 종료\n061-452-4911\n휴대전화로 보내기\n비즈니스에 대한 소유권 주장\n\ue3c9\n수정 제안하기\n누락된 정보 추가\n웹사이트 추가\n사진\n전체\n스트리트 뷰 및 360°\n사진 추가\n여기에 필요한 게 없나요?\n보통은 20분 안에 커뮤니티에서 질문에 답변합니다.\n커뮤니티에 질문하기\n  리뷰 요약\n5\n4\n3\n2\n1\n2.3\n리뷰 4개\n리뷰 작성\n리뷰\n정렬\nhojun yoon\n지역 가이드 · 리뷰 14개 · 사진 177장\n5년 전\n망했다. 왜망했는지는 알것같다. 비싸고 맛없다.\n좋아요\n공유\nseol경수\n1년 전\n현미경\n지역 가이드 · 리뷰 59개 · 사진 359장\n3년 전\n리뷰 더보기 (1)\n함께 검색한 장소\n더꽃길참치\n리뷰 없음\n일식\n지중해\n4.3(50)\n해산물 요리\n바다촌\n3.8(119)\n음식점\n타쿠미\n4.3(35)\n초밥\n동경스시\n2.0(1)\n초밥\n  웹 검색결과\n  데이터 정보', "오사카 성 천수각\n大阪城天守閣\n4.5\n(4,250)\n성곽\n개요\n리뷰\n정보\n\ue52e\n경로\n\ue866\n저장\n\uf05f\n주변\n\ue702\n휴대전화로 보내기\n\ue80d\n공유\n오사카성 단지에 우뚝 솟아 있는 인상적인 다층탑으로 금박 세공으로 장식했으며 박물관이 있습니다.\n입장권\n검색 결과 정보\n장소 입장 가능\n오사카 성 천수각\n공식 사이트\n₩5,224\nVELTRA\n₩5,224\n모바일 티켓\nアソビュー！\n₩5,224\n즉시 확인 · 모바일 티켓\n펼치기\n1-1 Osakajo, Chuo Ward, Osaka, 540-0002 일본\n위치: 오사카 성\n영업 종료 ⋅ 월 오전 9:00에 영업 시작\nosakacastle.net\n+81 6-6941-3044\nMGPG+W8 오사카시 일본 오사카부\n휴대전화로 보내기\n\ue3c9\n수정 제안하기\n고객의 업데이트\nIt was one of the most beautiful castle I've ever seen.\n3달 전\n  인기 시간대\n일요일 \n\ue408\nAM 6시\nAM 9시\nPM 12시\nPM 3시\nPM 6시\nPM 9시\n\ue409\n사진\n전체\n최신\n오늘\n동영상\n미라이자 오사카성\n오사카 성\n시노비야 오사카성점\n오사카 성 사쿠라 몬\n호코쿠 신사\n오사카 성 호포\n스트리트 뷰 및 360°\n사진 추가\n입점 매장\n大阪城天守閣ミュージアムショップ\n4.5(11)\n선물 가게 · 1층\nCastle Keep Entry Ticket Office\n4.3(9)\n박물관 · 1층\n영업 종료 ⋅ 월 오전 9:00에 영업 시작\n질문과 답변\n(Google 번역) 2023년 7월 18일은 평소대로 영업하나요? (원본) 18 july 2023 opearating as usual?\n(Google 번역) 오픈 예정입니다. 재미있게 (원본) It is scheduled to open. have fun\n답변 2개 보기\n4달 전\n\n질문 더보기\n커뮤니티에 질문하기\n  리뷰 요약\n5\n4\n3\n2\n1\n4.5\n리뷰 4,250개\n리뷰 작성\n리뷰\n정렬\n전체\n엘리베이터\n158\n도요토미 히데요시\n112\n전망대\n44\n일본의 역사\n21\n+5\n오세훈\n지역 가이드 · 리뷰 56개 · 사진 446장\n1달 전\n외관은 정말 멋있지만, 내부는 볼거리가 크게 많지는 않습니다.\n전망대 정도는 오사카 시내가 다 보여서 가보시는 것을 추천드려요. 천수각 내부에는 도요토미 히데요시의 일대기 등 일본의 역사를 전시해놓아서 크게 흥미가 가지는 않았어요. 자세히\n3\n공유\nYerim Jo\n리뷰 10개 · 사진 31장\n1달 전\n주유패스가 있다면 입장료가 무료, 지하철역 개찰구에서 뽑는 1DayPass가 있다면 입장료 할인 가능합니다.\n직원분께서 안내도 잘 해주시니 패스 있는 분들은 참고해주세요.\n천수각 전망대 올라가는 방법은 엘리베이터와 계단이 있는데 모든 관광객이 엘리베이터에만 줄을 서있기 때문에 계단으로 올라가는걸 추천드립니다.\n8층이긴 하지만 층마다 박물관처럼 볼거리가 많아 쉬엄쉬엄 올라갈 수 있습니다. 아픈 역사와도 관련이 깊은만큼 많은 것을 느끼고 올 수 있는 곳입니다. 자세히\n1\n공유\nSJ Lee\n지역 가이드 · ...
